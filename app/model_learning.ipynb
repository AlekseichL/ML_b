# %% [markdown]
# # Step 1 - TRAIN

# %%
import pandas as pd
import dill
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.metrics import roc_auc_score, roc_curve, precision_recall_curve
from sklearn.metrics import f1_score

#working with text
from sklearn.feature_extraction.text import TfidfVectorizer

#normalizing data
from sklearn.preprocessing import StandardScaler

#pipeline
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import precision_score,recall_score

#imputer
from sklearn.impute import SimpleImputer

import sklearn.datasets

# %%
df = pd.read_csv("fake_job_postings.csv")
df.head(3)
# Out:
#    job_id                                      title          location  \
# 0       1                           Marketing Intern  US, NY, New York
# 1       2  Customer Service - Cloud Video Production    NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)     US, IA, Wever
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# 2  Our client, located in Houston, is actively se...
#
#                                         requirements  \
# 0  Experience with content management systems a m...
# 1  What we expect from you:Your key responsibilit...
# 2  Implement pre-commissioning and commissioning ...
#
#                                             benefits  telecommuting  \
# 0                                                NaN              0
# 1  What you will get from usThrough being part of...              0
# 2                                                NaN              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0           Other          Internship
# 1                 1              0       Full-time      Not Applicable
# 2                 1              0             NaN                 NaN
#
#   required_education                   industry          function  fraudulent
# 0                NaN                        NaN         Marketing           0
# 1                NaN  Marketing and Advertising  Customer Service           0
# 2                NaN                        NaN               NaN           0

# %%
df['fraudulent'].value_counts()
# Out:
# fraudulent
# 0    17014
# 1      866
# Name: count, dtype: int64

# %% [markdown]
# ### Разделим данные на train/test и сохраним тестовую выборку на диск

# %%
X_train, X_test, y_train, y_test = train_test_split(df, df['fraudulent'], test_size=0.33, random_state=42, stratify=df['fraudulent'])
# save test
X_test.to_csv("data/X_test.csv", index=None)
y_test.to_csv("data/y_test.csv", index=None)

# save train
X_train.to_csv("data/X_train.csv", index=None)
y_train.to_csv("data/y_train.csv", index=None)

# %%
class ColumnSelector(BaseEstimator, TransformerMixin):
    """
    Transformer to select a single column from the data frame to perform additional transformations on
    """
    def __init__(self, key):
        self.key = key

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        return X[self.key]


class TextImputer(BaseEstimator, TransformerMixin):
    def __init__(self, key, value):
        self.key = key
        self.value = value

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        X[self.key] = X[self.key].fillna(self.value)
        return X

# %%
features = ['description', 'company_profile', 'benefits', 'requirements']
target = 'fraudulent'

# %% [markdown]
# ### Соберем кусок, ответственный за feature engineering

# %%
# combine
description = Pipeline([
                ('imputer', TextImputer('description', '')),
                ('selector', ColumnSelector(key='description')),
                ('tfidf', TfidfVectorizer())
            ])

company_profile = Pipeline([
                ('imputer', TextImputer('company_profile', '')),
                ('selector', ColumnSelector(key='company_profile')),
                ('tfidf', TfidfVectorizer())
            ])

benefits = Pipeline([
                ('imputer', TextImputer('benefits', '')),
                ('selector', ColumnSelector(key='benefits')),
                ('tfidf', TfidfVectorizer())
            ])

requirements = Pipeline([
                ('imputer', TextImputer('requirements', '')),
                ('selector', ColumnSelector(key='requirements')),
                ('tfidf', TfidfVectorizer())
            ])


feats = FeatureUnion([('description', description),
                      ('company_profile', company_profile),
                      ('benefits', benefits),
                      ('requirements', requirements)])

# %% [markdown]
# ### Добавим классификатор

# %%
# %%time

pipeline = Pipeline([
    ('features', feats),
    ('classifier', LogisticRegression()),
])

pipeline.fit(X_train, y_train)
# Out:
# CPU times: total: 3.77 s
# Wall time: 3.76 s
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('description',
#                                                  Pipeline(steps=[('imputer',
#                                                                   TextImputer(key='description',
#                                                                               value='')),
#                                                                  ('selector',
#                                                                   ColumnSelector(key='description')),
#                                                                  ('tfidf',
#                                                                   TfidfVectorizer())])),
#                                                 ('company_profile',
#                                                  Pipeline(steps=[('imputer',
#                                                                   TextImputer(key='company_profile',
#                                                                               value='')),
#                                                                  ('selector',
#                                                                   ColumnSelector(key='company...
#                                                 ('benefits',
#                                                  Pipeline(steps=[('imputer',
#                                                                   TextImputer(key='benefits',
#                                                                               value='')),
#                                                                  ('selector',
#                                                                   ColumnSelector(key='benefits')),
#                                                                  ('tfidf',
#                                                                   TfidfVectorizer())])),
#                                                 ('requirements',
#                                                  Pipeline(steps=[('imputer',
#                                                                   TextImputer(key='requirements',
#                                                                               value='')),
#                                                                  ('selector',
#                                                                   ColumnSelector(key='requirements')),
#                                                                  ('tfidf',
#                                                                   TfidfVectorizer())]))])),
#                 ('classifier', LogisticRegression())])

# %% [markdown]
# ### Посмотрим, как выглядит pipeline

# %%
pipeline.steps
# Out:
# [('features',
#   FeatureUnion(transformer_list=[('description',
#                                   Pipeline(steps=[('imputer',
#                                                    TextImputer(key='description',
#                                                                value='')),
#                                                   ('selector',
#                                                    ColumnSelector(key='description')),
#                                                   ('tfidf', TfidfVectorizer())])),
#                                  ('company_profile',
#                                   Pipeline(steps=[('imputer',
#                                                    TextImputer(key='company_profile',
#                                                                value='')),
#                                                   ('selector',
#                                                    ColumnSelector(key='company_profile')),
#                                                   ('tfidf', TfidfVectorizer())])),
#                                  ('benefits',
#                                   Pipeline(steps=[('imputer',
#                                                    TextImputer(key='benefits',
#                                                                value='')),
#                                                   ('selector',
#                                                    ColumnSelector(key='benefits')),
#                                                   ('tfidf', TfidfVectorizer())])),
#                                  ('requirements',
#                                   Pipeline(steps=[('imputer',
#                                                    TextImputer(key='requirements',
#                                                                value='')),
#                                                   ('selector',
#                                                    ColumnSelector(key='requirements')),
#                                                   ('tfidf',
#                                                    TfidfVectorizer())]))])),
#  ('classifier', LogisticRegression())]

# %% [markdown]
# ### Сохраним модель (пайплайн)

# %%
with open("models/logreg_pipeline.dill", "wb") as f:
    dill.dump(pipeline, f)

# %% [markdown]
# # Step 2 - PREDICT

# %% [markdown]
# ### Проверка работоспособности и качества пайплайна

# %%
X_test = pd.read_csv("data/X_test.csv")
y_test = pd.read_csv("data/y_test.csv")

# %%
X_test.head(3)
# Out:
#    job_id                                        title            location  \
# 0    1511                     Marketing Representative  US, CA, Sacramento
# 1   17531                  Casual job/Immediate start               AU, ,
# 2   10898  Office Manager -  Professional Multi-tasker              US, ,
#
#   department salary_range                                    company_profile  \
# 0        NaN          NaN  Tidewater Finance Co. was established in 1992 ...
# 1        NaN          NaN                                                NaN
# 2        NaN  40000-47000  Airenvy’s mission is to provide lucrative yet ...
#
#                                          description  \
# 0  Financial Services Company is seeking a full-t...
# 1   Looking for  work?We are looking for a self m...
# 2  Who is Airenvy?Hey there! We are seasoned entr...
#
#                                         requirements  \
# 0  This position requires the following qualifica...
# 1      - No experience necessary - Training provided
# 2  High-School diploma Extremely organizedProcess...
#
#                                             benefits  telecommuting  \
# 0  Our company offers a competitive salary as wel...              0
# 1        - GREAT TEAM CULTURE AND IMMEDIATE START!!!              0
# 2  Competitive Pay. You'll be able to eat steak e...              0
#
#    has_company_logo  has_questions employment_type required_experience  \
# 0                 1              0       Full-time           Associate
# 1                 0              0             NaN                 NaN
# 2                 1              1       Full-time         Entry level
#
#           required_education            industry        function  fraudulent
# 0                Unspecified  Financial Services       Marketing           0
# 1                        NaN                 NaN             NaN           1
# 2  High School or equivalent            Internet  Administrative           0

# %%
with open('models/logreg_pipeline.dill', 'rb') as in_strm:
    pipeline = dill.load(in_strm)

# %%
pipeline
# Out:
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('description',
#                                                  Pipeline(steps=[('imputer',
#                                                                   TextImputer(key='description',
#                                                                               value='')),
#                                                                  ('selector',
#                                                                   ColumnSelector(key='description')),
#                                                                  ('tfidf',
#                                                                   TfidfVectorizer())])),
#                                                 ('company_profile',
#                                                  Pipeline(steps=[('imputer',
#                                                                   TextImputer(key='company_profile',
#                                                                               value='')),
#                                                                  ('selector',
#                                                                   ColumnSelector(key='company...
#                                                 ('benefits',
#                                                  Pipeline(steps=[('imputer',
#                                                                   TextImputer(key='benefits',
#                                                                               value='')),
#                                                                  ('selector',
#                                                                   ColumnSelector(key='benefits')),
#                                                                  ('tfidf',
#                                                                   TfidfVectorizer())])),
#                                                 ('requirements',
#                                                  Pipeline(steps=[('imputer',
#                                                                   TextImputer(key='requirements',
#                                                                               value='')),
#                                                                  ('selector',
#                                                                   ColumnSelector(key='requirements')),
#                                                                  ('tfidf',
#                                                                   TfidfVectorizer())]))])),
#                 ('classifier', LogisticRegression())])

# %%
preds = pipeline.predict_proba(X_test)[:, 1]

pred_df = pd.DataFrame({'preds': preds})
pred_df.to_csv("test_predictions.csv", index=None)

# %%
preds[:10]
# Out:
# array([0.01947227, 0.32992821, 0.02001141, 0.02618238, 0.00356344,
#        0.00249822, 0.02481659, 0.00263951, 0.00316769, 0.00364648])

# %%
precision, recall, thresholds = precision_recall_curve(y_test, preds)

fscore = (2 * precision * recall) / (precision + recall)
# locate the index of the largest f score
ix = np.argmax(fscore)
print(f'Best Threshold={thresholds[ix]}, F-Score={fscore[ix]:.3f}, Precision={precision[ix]:.3f}, Recall={recall[ix]:.3f}')
# Out:
# Best Threshold=0.20669968796447724, F-Score=0.853, Precision=0.875, Recall=0.832
